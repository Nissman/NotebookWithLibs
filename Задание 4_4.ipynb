# %%
import numpy
import pandas as pd
import matplotlib.pyplot
df=pd.read_csv('winequality-white.csv', delimiter=';')
df=df.loc[df['residual sugar']<1]
df=df[['density','pH']]
#df=df.iloc[:,7:9]
df=df.iloc[0::2]
matplotlib.pyplot.hist(df['pH'])
# Out:
# (array([5., 1., 6., 7., 5., 6., 4., 2., 1., 2.]),
#  array([2.9  , 2.964, 3.028, 3.092, 3.156, 3.22 , 3.284, 3.348, 3.412,
#         3.476, 3.54 ]),
#  <a list of 10 Patch objects>)

# %%
import numpy
import pandas as pd
import matplotlib.pyplot
df=pd.read_csv('winequality-white.csv', delimiter=';')
df=df.loc[df['residual sugar']<1]
df=df[['density','pH']]
#df=df.iloc[:,7:9]
df=df.iloc[0::2]
matplotlib.pyplot.hist(df['density'])
# Out:
# (array([1., 6., 2., 6., 0., 4., 3., 6., 4., 7.]),
#  array([0.9888 , 0.98926, 0.98972, 0.99018, 0.99064, 0.9911 , 0.99156,
#         0.99202, 0.99248, 0.99294, 0.9934 ]),
#  <a list of 10 Patch objects>)

# %%
 Вернитесь к файлу «empty_notebook.ipynb», открытому в Binder. 
    • Используя DataFrame, полученный в предыдущем пункте, постройте гистограмму значений в столбце «pH».
    • Используя DataFrame, полученный в предыдущем пункте, постройте график для значений в столбце «density».
    • Сохраните файл Jupyter notebook с названием «Задание 4_4.ipynb» и загрузите его в созданный репозиторий.
